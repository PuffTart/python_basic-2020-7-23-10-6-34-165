# %%
import numpy as np
from PIL import Image  # pliilw 包
import matplotlib.pyplot as plt
from matplotlib import image as mp  # 用于将图片转为数组形式

# %%
colour_array = mp.imread(r'C:\Users\surface\Downloads\python_basic-2020-7-23-10-6-34-165-master\image.jpg')   
#显示彩色图片
plt.figure()
plt.imshow(colour_array)

# %%
def rgb_to_gray(array):
    #定义一个空列表
    x = []
    for i in range(array.shape[0]):
        y = []
        for j in range(array.shape[1]):
            #使用转换公式进行彩色灰度转换
            y.append(np.int(array[i,j,0]/3+array[i,j,1]/3+array[i,j,2]/3))
        x.append(y)
    gray_array = np.array(x)
    return x

# %%
gray_array = rgb_to_gray(colour_picture)
plt.figure()
plt.imshow(gray_array,cmap = plt.get_cmap('gray'))
